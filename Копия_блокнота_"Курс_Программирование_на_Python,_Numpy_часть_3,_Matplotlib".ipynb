# %% [markdown]
# <a href="https://colab.research.google.com/github/DokinAlex/python2/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9A%D1%83%D1%80%D1%81_%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%BD%D0%B0_Python%2C_Numpy_%D1%87%D0%B0%D1%81%D1%82%D1%8C_3%2C_Matplotlib%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Cesencom, Центр Системно-Инженерных Компетенций, ООО "Цесинком"

# %% [markdown]
# #**Курс "Программирование на Python, Numpy для Data Science часть 3, Matplotlib"**

# %% [markdown]
# ##10. Визуализация массивов с помощью Matplotlib.
# Matplotlib — мультиплатформенная библиотека для визуализации данных, основанная на массивах библиотеки NumPy.

# %% [markdown]
# ###10.1 О библиотеке Matplotlib.
# Применим стандартные сокращения для импортов библиотеки Matplotlib:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Для выбора подходящих стилей для наших графиков мы будем применять директиву `plt.style`

# %%
plt.style.use('classic') # задает директиву classic, которая обеспечит в графиках классический стиль библиотеки

# %% [markdown]
# Функция `plt.show()` ищет все активные в настоящий момент объекты графиков и открывает одно или несколько интерактивных окон для отображения вашего графика (графиков)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# Интерактивное построение графиков в блокноте  возможно с помощью
# команды `%matplotlib`:
#
# *   `%matplotlib notebook` - приведет к включению в блокнот
# интерактивных графиков
# *   `%matplotlib inline` - приведет к включению в блокнот
# статических изображений графиков
# После выполнения этой команды (которое нужно произвести только один раз за сеанс/для одного ядра Python) все создающие графики блоки в блокноте будут включать PNG-изображения итогового графика

# %%
# %matplotlib inline
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# Сохранить предыдущий рисунок в файл PNG
# можно с помощью команды `savefig()`

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# ###Два интерфейса Matplotlib
# Два интерфейса библиотеки Matplotlib:
# *   MATLAB-подобный интерфейс, основанный на сохранении состояния
# *   обладающий большими возможностями объектно-ориентированный интерфейс

# %% [markdown]
# **Интерфейс в стиле MATLAB**
#
# Библиотека Matplotlib изначально была написана как альтернативный вариант (на языке Python) для пользователей пакета MATLAB

# %%
plt.figure() #Создаем рисунок для графика
plt.subplot(2, 1, 1) # (rows, columns, panel number) Создаем первую из двух областей графика и задаем текущую ось
plt.plot(x, np.sin(x))
plt.subplot(2, 1, 2) # Создаем вторую область и задаем текущую ось
plt.plot(x, np.cos(x))

# %% [markdown]
# Этот интерфейс сохраняет состояние: он отслеживает текущий
# рисунок и его оси координат и для него выполняет все команды plt.Хотя в случае простых графиков этот интерфейс с сохранением состояния быстр и удобен, его использование может привести к проблемам. Например, как после создания второй области рисунка вернуться в первую и добавить что-либо в ней.

# %% [markdown]
# **Объектно-ориентированный интерфейс**
#
# Объектно-ориентированный интерфейс подходит для более сложных ситуаций, когда вам требуется больше возможностей управления рисунком. В объектно-ориентированном интерфейсе функции рисования не полагаются на понятие текущего рисунка или осей, а являются методами явным образом определяемых объектов
# Figure и Axes.

# %%
# Сначала создаем сетку графиков
# ax будет массивом из двух объектов Axes
fig, ax = plt.subplots(2)
# Вызываем метод plot() соответствующего объекта
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# В случае более простых графиков выбор интерфейса в основном вопрос личных предпочтений, но по мере усложнения графиков объектно-ориентированный подход становится необходимостью.

# %% [markdown]
# Для большинства функций интерфейса `plt` соответствующие методы интерфейса `ax` носят такое же название (например, `plt.plot() → ax.plot()`, `plt.legend() → ax.legend()` и т. д.), это касается не всех команд:
#
# *   `plt.xlabel() → ax.set_xlabel()`
# *   `plt.ylabel() → ax.set_ylabel()`
# *   `plt.xlim() → ax.set_xlim()`
# *   `plt.ylim() → ax.set_ylim()`
# *   `plt.title() → ax.set_title()`

# %% [markdown]
# ###10.2 Простые линейные графики.
# Простейшим из всех графиков является визуализация отдельной функции `y = f(x)`

# %%
# начнем с настройки блокнота для построения графиков и импорта функций
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# Во всех графиках Matplotlib мы начинаем с создания рисунка и системы координат.
# В простейшем случае рисунок и систему координат можно создать следующим образом

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
# те графики в объектно-ориентированном интерфейсе
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))
ax.plot(x, np.cos(x))

# %% [markdown]
# ### **Практическое задание**
#
#
# 1.   Создайте массив  х из 50 значений равномерно распределенных между 0 и 10
# 2.   Создайте масиив значений y удовлетворяющему правилу y=sin(x)**2
# 1.   Визуализируйте график с помощью интерфеса MATLAB
# 2.   Визуализируйте график с помощью объектно-ориентированного интерфеса

# %%
# начнем с настройки блокнота для построения графиков и импорта функций
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
x = np.linspace(0, 10, 50)
y=np.sin(x)**2
plt.plot(x, y)
fig = plt.figure()
ax = plt.axes()
ax.plot(x, y)

# %% [markdown]
# **Настройка графика: цвета и стили линий.**
#
# Для настройки цвета используется ­
# ключевое слово `color` , которому ставится в соответствие строковый аргумент, задающий практически любой цвет.

# %%
plt.plot(x, np.sin(x - 0), color='blue') # Задаем цвет по названию
plt.plot(x, np.sin(x - 1), color='g') # Краткий код цвета (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Шкала оттенков серого цвета, значения в диапазоне от 0 до 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # 16-ричный код (RRGGBB от 00 до FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # Кортеж RGB, значения 0 и 1
plt.plot(x, np.sin(x - 5), color='chartreuse') # Поддерживаются все названия цветов HTML

# %% [markdown]
# Стиль линий можно настраивать и с помощью ключевого слова `linestyle`

# %%
plt.plot(x,x+0,linestyle='solid')
plt.plot(x,x+1,linestyle='dashed')
plt.plot(x,x+2,linestyle='dashdot')
plt.plot(x,x+3,linestyle='dotted')
# Можно использовать и следующие сокращенные коды:
plt.plot(x, x + 4, linestyle='-') # сплошная линия
plt.plot(x, x + 5, linestyle='--') # штриховая линия
plt.plot(x, x + 6, linestyle='-.') # штрихпунктирная линия
plt.plot(x, x + 7, linestyle=':'); # пунктирная линия

# %% [markdown]
# ### **Практическое задание**
#
#
# 1.   Воспользуйтесь данными из прошлого задания
# 2.   Визуализируйте несколько графиков,минимум 8 на одном пространстве, для этого используйте смещение + 0.5. При отрисовке каждого графика необходимо использовать различные стили и цвета.
# 1.   Визуализируйте график с помощью любого интерфеса

# %%
#print (x,y)
fig1 = plt.figure()
ax1 = plt.axes()

ax1.plot(x, y+0.0,linestyle='-', color='red')
ax1.plot(x, y+0.5,linestyle='--', color='red')
ax1.plot(x, y+1.0,linestyle='-.', color='red')
ax1.plot(x, y+1.5,linestyle=':', color='red')
ax1.plot(x, y+2.0,linestyle='-', color='blue')
ax1.plot(x, y+2.5,linestyle='--', color='yellow')
ax1.plot(x, y+3.0,linestyle='-.', color='green')
ax1.plot(x, y+3.5,linestyle=':', color='gray')

# %% [markdown]
# **Настройка графика: пределы осей координат**
#
# Библиотека Matplotlib достаточно хорошо подбирает пределы осей координат по умолчанию, но иногда требуется более точная настройка. Простейший способ настройки пределов осей координат — методы `plt.xlim()` и `plt.ylim()`

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# Метод `plt.axis()` предоставляет возможность задавать пределы осей X и Y с помощью одного вызова путем передачи списка, в котором указываются `[xmin, xmax, ymin, ymax]`

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# (-1.0, 11.0, -1.5, 1.5)

# %% [markdown]
# **Метки на графиках**
#
# Названия и метки осей — простейшие из подобных меток.

# %%
plt.plot(x, np.sin(x))
plt.title("Синусоидальная кривая") # задаем титульную надпись
plt.xlabel("x") # задаем подпись под осью Х
plt.ylabel("sin(x)") # задаем подпись под осью Y
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# В случае отображения нескольких линий в одной координатной сетке удобно создать легенду для графика, на которой бы отмечался каждый тип линии. Функция `plt.legend()` отслеживает стиль и цвет линии и устанавливает их соответствие с нужной меткой.

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal') # выровнять соотношение сторон графика, чтобы  длина равных приращений по осям X и Y выглядела одинаковой
plt.legend()

# %% [markdown]
# В объектно-ориентированном интерфейсе построения графиков вместо того, чтобы вызывать эти функции по отдельности, удобнее воспользоваться методом `ax.set()`, чтобы задать значения всех этих параметров за один раз.

# %%
ax = plt.axes()
ax.plot(x, np.sin(x),'-g', label='sin(x)')
ax.set(xlim=(0, 10), ylim=(-2, 2),
      xlabel='x', ylabel='sin(x)', 
      title='Простая диаграмма');
ax.legend()

# %% [markdown]
# ### **Практическое задание**
#
#
# 1.   Воспользуйтесь данными из первого задания
# 2.   Визуализируйте метки (легенды и титульная надпись)
# 1.   Задайте собственные пределы осей
# 1.   Визуализируйте график с помощью любого интерфеса Matplotlib

# %%
#print (x,y)
fig1 = plt.figure()
ax1 = plt.axes()

ax1.plot(x, y+0.0,linestyle='-', color='red', label='0.0')
ax1.plot(x, y+0.5,linestyle='--', color='red', label='0.5')
ax1.plot(x, y+1.0,linestyle='-.', color='red', label='1.0')
ax1.plot(x, y+1.5,linestyle=':', color='red', label='1.5')
ax1.plot(x, y+2.0,linestyle='-', color='blue', label='2.0')
ax1.plot(x, y+2.5,linestyle='--', color='yellow', label='2.5')
ax1.plot(x, y+3.0,linestyle='-.', color='green', label='3.0')
ax1.plot(x, y+3.5,linestyle=':', color='gray', label='3.5')

ax1.set(xlim=(2.5, 7), ylim=(-2, 20), title='Мои графики');
ax1.legend()

# %% [markdown]
# ###10.3 Простые диаграммы рассеяния.
# Еще один часто используемый тип графиков — диаграммы рассеяния, родственные линейным графикам. В них точки не соединяются отрезками линий, а представлены по отдельности точками, кругами или другими фигурами на графике.

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, y, 'o', color='black')

# %% [markdown]
# Построение диаграмм рассеяния с помощью функции `plt.scatter`

# %%
plt.scatter(x, y, marker='o')

# %% [markdown]
# Основное различие между функциями plt.scatter и plt.plot состоит в том, что с помощью первой можно создавать диаграммы рассеяния с индивидуально задаваемыми (или выбираемыми в соответствии с данными) свойствами каждой точки
# (размер, цвет заливки, цвет рамки и т. д.)

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
plt.title("Изменение размера, цвета и прозрачности точек на диаграмме рассеяния")
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,cmap='viridis')
plt.colorbar(); # Отображаем цветовую шкалу

# %% [markdown]
# ### **Практическое задание**
#
#
# 1.   Воспользуйтесь данными из первого задания
# 2.   Визуализируйте данные с помощью скаттера
# 1.   Задайте собственные кастомные настройки для каждой точки
# 1.   Визуализируйте график с помощью любого интерфеса Matplotlib

# %%
rng = np.random.RandomState(17)
x = rng.randn(10)
y = rng.randn(10)
colors = rng.rand(10)**2
print (colors)
plt.title("Изменение размера, цвета и прозрачности точек на диаграмме рассеяния")
sizes = 10000 * rng.rand(10)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.8,cmap='viridis')
plt.colorbar(); # Отображаем цветовую шкалу
# Out:
# [0.02277283 0.00305161 0.51557741 0.08544944 0.03951105 0.69116597
#  0.32261391 0.00677983 0.29702345 0.02526788]

# %% [markdown]
# ###10.4 Визуализация погрешностей.
# Точный учет погрешностей, как и точная информация о самих значениях важен для любых научных измерений.
#
# **Простые планки погрешностей**
#
# Простые планки погрешностей можно создать с помощью вызова всего одной функции библиотеки Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
plt.title("Пример планок погрешностей")
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# У функции errorbar есть множество параметров для
# тонкой настройки выводимых данных. С помощью этих дополнительных
# параметров вы можете легко настроить в соответствии со своими требованиями внешний вид графика планок погрешностей. Планки погрешностей удобно делать более светлыми, чем точки, особенно на насыщенных графиках

# %%
plt.title("Пользовательские настройки планок погрешностей")
plt.errorbar(x, y, yerr=dy, fmt='o', color='black', ecolor='lightgray', elinewidth=3, capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### **Практическое задание**
#
#
# 1.   Воспользуйтесь данными из первого задания
# 2.   Визуализируйте данные с простых планок погрешностей, задав самостоятелно dy
# 1.   Поэксперементируйте с различными параметрами errorbar и визуализируйте их
# 1.   Визуализируйте график с помощью любого интерфеса Matplotlib

# %%
plt.style.use('seaborn-whitegrid')
plt.title("Пример планок погрешностей")
x = np.linspace(0, 10, 20)
y1=np.ones(20)
y1[:]=10
y2=np.ones(20)
y2[:]=-10
dy = 10.2
y = np.sin(x)*np.cos(x) + np.random.randn(20)
#plt.errorbar(x, y, yerr=dy, fmt='.k')
plt.errorbar(x, y, yerr=dy, fmt='x', color='red', ecolor='yellow', elinewidth=8, capsize=60)
plt.xlim(-1, 20)
plt.ylim(-20, 40)
plt.plot(x, y1, '-', color='blue')
plt.plot(x, y2, '-', color='blue')

# %% [markdown]
# **Непрерывные погрешности**
#
# В некоторых случаях нужно отображать планки погрешностей для непрерывных величин. В библиотеке Matplotlib отсутствует встроенная утилита для решения данной задачи. Но это можно составит с помощью `plt.plot` и `plt.fill_between`, для получения искомого результата.

# %%
# Подготовим данные: простую регрессию на основе Гауссова процесса
from sklearn.gaussian_process import GaussianProcessRegressor
# Описываем модель и отрисовываем некоторые данные
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)
# Выполняем подгонку Гауссова процесса
gp = GaussianProcessRegressor()
gp.fit(xdata[:, np.newaxis], ydata)
xfit = np.linspace(0, 10, 1000)
yfit, MSE = gp.predict(xfit[:, np.newaxis],return_std=True)
dyfit = 2 * np.sqrt(MSE) # 2*сигма ~ область с уровнем доверия 95%

# %%
# Визуализируем результат
plt.title("Непрерывная погрешность")
plt.plot(xdata, ydata, 'or')
plt.plot(xfit, yfit, '-', color='gray')
plt.fill_between(xfit, yfit - dyfit, yfit + dyfit, color='green', alpha=0.2)
plt.xlim(0, 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Воспользуйтесь данными из первого задания
# 2.   Подготовте данные: простую регрессию на основе Гауссова процесса
# 1.   Визулизируйте результат отображения непрерывной погрешности с помощью любого интерфеса Matplotlib

# %% [markdown]
# ###10.5 Графики плотности и контурные графики.
# Иногда удобно отображать трехмерные данные в двумерной плоскости с помощью контуров или областей, кодированных различными цветами. Существует три предназначенные для этой цели функции библиотеки Matplotlib:
#
# *   `plt.contour` - для контурных графиков
# *   `plt.contourf` - для контурных графиков с заполнением
# *   `plt.imshow` - для отображения изображений

# %%
def f(x, y):
  return (1 - y**5 + x**5)*np.exp(-x**2-y**2)

dx = 0.01; dy = 0.01
x = np.arange(-2.0,2.0,dx)
y = np.arange(-2.0,2.0,dy)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)
plt.title("Визуализация трехмерных данных с помощью контуров")
plt.contour(X, Y, Z, colors='black')

# %% [markdown]
# Можно также кодировать линии различными цветами, задав карты
# цветов с помощью аргумента cmap . В данном случае мы также указали, что хотели бы нарисовать больше линий — разделить данные на 20 интервалов с равными промежутками.

# %%
plt.title("Визуализация трехмерных данных с помощью разноцветных контуров")
plt.contour(X, Y, Z, 20, cmap='RdGy')

# %% [markdown]
# Можно, воспользовавшись контурным графиком с заполнением, доступным посредством функции `plt.contourf()`. Вдобавок воспользуемся командой `plt.colorbar()`, автоматически создающей
# для графика дополнительную ось с маркированной информацией о цвете.

# %%
plt.title("Визуализация трехмерных данных с помощью заполненных контуров")
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# Шкала цветов наглядно демонстрирует, что черные области — точки максимума, а красные — точки минимума.

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Воспользуйтесь данными из текущего задания
# 2.   Используя визуализацию текущего задания, попробуйте поэксперементировать с аргументами функций, для получения результата отличного от имеющего
# 1.   Визулизируйте результат отображения трехмерных данных с помощью любого объектно-ориентированного интерфеса Matplotlib

# %%
#'viridis'
#https://matplotlib.org/stable/tutorials/colors/colormaps.html

a=['viridis', 'plasma', 'inferno', 'magma', 'cividis', 'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
           'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu','GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']

plt.contourf(X, Y, Z*(-1), 10, cmap=a[-1])
plt.colorbar()

# %% [markdown]
# ###10.6 Гистограммы, разбиения по интервалам и плотность.
# Простая гистограмма может принести огромную пользу при первичном анализе набора данных.

# %%
data = np.random.randn(1000)
# пример гистограммы с детальными пользовательскими настройками
plt.hist(data, bins=30, alpha=0.6,
        histtype='stepfilled', color='steelblue', edgecolor='none')
# Out:
# (array([ 1.,  2.,  2.,  4., 11., 10., 15., 19., 40., 52., 66., 62., 76.,
#         69., 92., 86., 66., 72., 56., 53., 37., 38., 27., 19., 13.,  2.,
#          4.,  2.,  1.,  3.]),
#  array([-3.1135948 , -2.908156  , -2.70271721, -2.49727841, -2.29183962,
#         -2.08640082, -1.88096203, -1.67552323, -1.47008444, -1.26464564,
#         -1.05920685, -0.85376805, -0.64832926, -0.44289046, -0.23745167,
#         -0.03201287,  0.17342593,  0.37886472,  0.58430352,  0.78974231,
#          0.99518111,  1.2006199 ,  1.4060587 ,  1.61149749,  1.81693629,
#          2.02237508,  2.22781388,  2.43325267,  2.63869147,  2.84413026,
#          3.04956906]),
#  <a list of 1 Patch objects>)

# %% [markdown]
# Сочетание опции `histtype='stepfilled'` с заданной прозрачностью alpha представляется очень удобным для сравнения гистограмм нескольких распределений.

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.5, bins=40) # normed=True,
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([ 2.,  0.,  2.,  3.,  1.,  2.,  7.,  5.,  8., 18., 33., 43., 35.,
#         45., 56., 71., 73., 65., 71., 71., 59., 64., 59., 43., 36., 28.,
#         27., 21., 14., 10.,  8.,  3.,  6.,  5.,  2.,  3.,  0.,  0.,  0.,
#          1.]),
#  array([-3.58935320e+00, -3.23142273e+00, -2.87349226e+00, -2.51556179e+00,
#         -2.15763132e+00, -1.79970086e+00, -1.44177039e+00, -1.08383992e+00,
#         -7.25909449e-01, -3.67978981e-01, -1.00485121e-02,  3.47881957e-01,
#          7.05812425e-01,  1.06374289e+00,  1.42167336e+00,  1.77960383e+00,
#          2.13753430e+00,  2.49546477e+00,  2.85339524e+00,  3.21132571e+00,
#          3.56925617e+00,  3.92718664e+00,  4.28511711e+00,  4.64304758e+00,
#          5.00097805e+00,  5.35890852e+00,  5.71683899e+00,  6.07476946e+00,
#          6.43269992e+00,  6.79063039e+00,  7.14856086e+00,  7.50649133e+00,
#          7.86442180e+00,  8.22235227e+00,  8.58028274e+00,  8.93821321e+00,
# ...

# %% [markdown]
# Если же нужно вычислить гистограмму (то есть подсчитать количество точек в заданном интервале) и не отображать ее, то для этих целей подходит функция `np.histogram()`

# %%
counts, bin_edges = np.histogram(x1, bins=5)
print(counts)
# Out:
# [ 27 230 424 283  36]

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Задайте массив Х1 из 500 случайных чисел распределенных на участке от 0 до 5
# 2.   Задайте массив Х2 из 500 случайных чисел распределенных на участке от -2 до 3
# 2.   Постройте простую гистограмму, распределения чисел в массивах, с использованием bins=20 и bins=10. Манипулируйте типом и прозрачностью гистограмм
# 1.   Визулизируйте результат с помощью любого интерфеса Matplotlib

# %%
rand = np.random.RandomState(111)
x1 = rand.random(500)*5
x2 = rand.random(500)*5-2
#print(x1,x2)
kwargs = dict(histtype='stepfilled', alpha=0.5, bins=20) # normed=True,
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
# Out:
# (array([25., 32., 19., 23., 27., 26., 28., 18., 33., 33., 24., 25., 27.,
#         13., 27., 27., 21., 28., 20., 24.]),
#  array([-1.97570982, -1.72717798, -1.47864615, -1.23011432, -0.98158249,
#         -0.73305066, -0.48451882, -0.23598699,  0.01254484,  0.26107667,
#          0.50960851,  0.75814034,  1.00667217,  1.255204  ,  1.50373583,
#          1.75226767,  2.0007995 ,  2.24933133,  2.49786316,  2.74639499,
#          2.99492683]),
#  <a list of 1 Patch objects>)

# %% [markdown]
# ###10.7 Пользовательские настройки легенд на графиках.
# Б*о*льшая понятность графика обеспечивается заданием меток для различных элементов графика.

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Синус')
ax.plot(x, np.cos(x), '--r', label='Косинус') 
ax.set_title('Легенда графика по умолчанию')
ax.axis('equal')
leg = ax.legend()

# %% [markdown]
# Существует множество вариантов пользовательских настроек такого графика, которые могут нам понадобиться.

# %%
ax.set_title('Легенда графика с пользовательскими настройками')
ax.legend(loc='upper left', frameon=False) # задать местоположение легенды и отключить рамку
fig

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Используя материалы текущего задания, разместите легенды в правом нижнем углу
# 2.   Измените цвет и тип линий графиков

# %%
ax.legend(loc='best', frameon=True) # задать местоположение легенды и отключить рамку
fig

# %% [markdown]
# ###10.8 Пользовательские настройки шкал цветов.
#
# Легенды графика отображают соответствие дискретных меток дискретным точкам.
# В случае непрерывных меток, базирующихся на цвете точек, линий или областей, подойдет такой инструмент, как шкала цветов. В библиотеке Matplotlib шкала цветов — отдельная система координат, предоставляющая ключ к значению цветов на графике.

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])
plt.imshow(I)
plt.colorbar()

# %% [markdown]
# Задать карту цветов можно с помощью аргумента `cmap` функции создания визуализации

# %%
plt.imshow(I, cmap='gray')

# %% [markdown]
# что существует три различные категории карт цветов:
# * последовательные карты цветов. Состоят из одной непрерывной последовательности цветов (например, binary или viridis );
# * дивергентные карты цветов. Обычно содержат два хорошо различимых цвета, отражающих положительные и отрицательные отклонения от среднего значения (например, RdBu или PuOr );
# * качественные карты цветов. В них цвета смешиваются без какого-либо четкого порядка (например, rainbow или jet ).

# %%
from matplotlib.colors import LinearSegmentedColormap
def grayscale_cmap(cmap):
  """Возвращает версию в оттенках серого заданной карты цветов"""
  cmap = plt.cm.get_cmap(cmap)
  colors = cmap(np.arange(cmap.N))
  # Преобразуем RGBA в воспринимаемую глазом светимость серого цвета
  RGB_weight = [0.299, 0.587, 0.114]
  luminance = np.sqrt(np.dot(colors[:, :3] ** 2, RGB_weight))
  colors[:, :3] = luminance[:, np.newaxis]
  return LinearSegmentedColormap.from_list(cmap.name + "_gray",
  colors, cmap.N)

def view_colormap(cmap):
  """Рисует карту цветов в эквивалентных оттенках серого"""
  cmap = plt.cm.get_cmap(cmap)
  colors = cmap(np.arange(cmap.N))
  cmap = grayscale_cmap(cmap)
  grayscale = cmap(np.arange(cmap.N))
  fig, ax = plt.subplots(2, figsize=(6, 2),
  subplot_kw=dict(xticks=[], yticks=[]))
  ax[0].imshow([colors], extent=[0, 10, 0, 1])
  ax[1].imshow([grayscale], extent=[0, 10, 0, 1])

# %%
view_colormap('jet') # Карта цветов jet и ее неравномерная шкала светимости

# %%
view_colormap('viridis') # Карта цветов viridis и ее равномерная шкала светимости

# %%
view_colormap('cubehelix') # Карта цветов cubehelix и ее светимость

# %%
view_colormap('RdBu') # RdBu (красно-синяя) карта цветов и ее светимость

# %%
plt.colormaps() # Псмотреть список карт цветов в Matplotlib
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
#  'YlOrRd_r',
#  'afmhot',
#  'afmhot_r',
# ...

# %% [markdown]
#   **Ограничения и расширенные возможности по использованию цветов**
#
# Библиотека Matplotlib предоставляет возможность разнообразных пользовательских настроек шкал цветов. Сами по себе шкалы цветов — просто экземпляры класса `plt.Axes`, поэтому для них можно использовать все уже изученные нами трюки, связанные с форматированием осей координат и делений на них. Шкалы цветов об-
# ладают достаточной гибкостью: например, можно сузить границы диапазона цветов, обозначив выходящие за пределы этого диапазона значения с помощью тре­угольных стрелок вверху и внизу путем задания значения свойства `extend` .

# %%
# создаем шум размером 1% от пикселов изображения
speckles = (np.random.random(I.shape) < 0.01)
I[speckles] = np.random.normal(0, 3, np.count_nonzero(speckles))
plt.figure(figsize=(10, 3.5))

plt.subplot(1, 2, 1)
plt.imshow(I, cmap='RdBu')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.imshow(I, cmap='RdBu')
plt.colorbar(extend='both')
plt.clim(-1, 1)

# %% [markdown]
# На левом рисунке зашумленные пикселы влияют на
# пределы диапазона цветов, по этой причине диапазон шума делает совершенно неразличимым интересующий нас паттерн. На правом рисунке задаем пределы диапазона цветов вручную и добавляем стрелки, указывающие на значения,выходящие за эти пределы. В результате получаем намного более удобную визуализацию наших данных

# %% [markdown]
#   **Дискретные шкалы цветов**
#
# Карты цветов по умолчанию непрерывны, но иногда нужно обеспечить отражение дискретных значений. Для этого можно воспользоваться
# функцией `plt.cm.get_cmap()`, передав в нее название подходящей карты цветов вместе с нужным количеством диапазонов

# %%
plt.imshow(I, cmap=plt.cm.get_cmap('Blues', 6))
plt.colorbar()
plt.clim(-1, 1)

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Используя материалы текущего задания, поэкспериментируйте с использованием различных карт цветов, добавлением количества шума

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

speckles = (np.random.random(I.shape) < 0.1)
I[speckles] = np.random.normal(0, 3, np.count_nonzero(speckles))
plt.figure(figsize=(10, 3.5))

plt.subplot(1, 2, 1)
plt.imshow(I, cmap='RdBu')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.imshow(I, cmap='RdBu')
plt.colorbar(extend='both')
plt.clim(-0.5, 0.5)

# %%
plt.imshow(I, cmap=plt.cm.get_cmap('Blues',3))
plt.colorbar()
plt.clim(-1, 1)

# %% [markdown]
# ###10.9 Множественные субграфики.
# Иногда удобно сравнить различные представления данных, разместив их друг с другом.
# В библиотеке Matplotlib на такой случай предусмотрено понятие субграфиков (subplots): несколько маленьких систем координат могут сосуществовать на одном рисунке.

# %%
ax1 = plt.axes() # обычные оси координат
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %% [markdown]
# Аналог этой команды в объектно-ориентированном интерфейсе — функция `fig.add_­axes()`. Воспользуемся ею для создания двух расположенных друг над другом систем координат

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                  xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                  ylim=(-1.2, 1.2))
x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %% [markdown]
# Бывают нужны выровненные столбцы или строки субграфиков. Функция `plt.subplot`, создающая отдельный субграфик внутри сетки,  принимает на входе три целочисленных аргумента — количество строк, количество столбцов и индекс создаваемого по такой схеме графика, отсчет которого начинается в верхнем левом
# углу и заканчивается в правом нижнем.

# %%
for i in range(1, 7):
  plt.subplot(2, 3, i)
  plt.text(0.5, 0.5, str((2, 3, i)),fontsize=18, ha='center')

# %% [markdown]
# Для настройки размеров полей между этими графиками можно выполнить команду `plt.subplots_adjust`.

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
  ax = fig.add_subplot(2, 3, i) # используем эквивалентную объектно-ориентированную команду
  ax.text(0.5, 0.5, str((2, 3, i)),fontsize=18, ha='center')

# %% [markdown]
# Удобнее использовать функцию `plt.subplots()`. Вместо отдельного субграфика эта функция создает целую сетку субграфиков одной строкой кода.

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')
# указание ключевых слов sharex и sharey приводит к автоматическому удалению внутренних меток с сетки

# %%
# Системы координат располагаются в двумерном массиве, индексируемом по [строка, столбец]
for i in range(2):
  for j in range(3):
    ax[i, j].text(0.5, 0.5, str((i, j)),fontsize=18, ha='center')
fig

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Создайте 4 субграфика, настройте размерность и удалите внутренние метки сетки
# 2.   Визуализируйте на каждом субграфике, функцию y=sin(x), для каждого следующего задайте смещение.

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np

# %%
fig1,ax1 = plt.subplots(sharex='col', sharey='row')

x = np.linspace(0, 10)
#, sharex='col', sharey='row'

for i in range(1, 5):
  ax1 = fig1.add_subplot(2, 2, i)
  ax1.plot(np.sin(x)+i/2)


#ax1.set(xlim=(2.5, 7), ylim=(-2, 20), title='Мои графики');
#ax1.set(sharex='col', sharey='row')

# %% [markdown]
# ###10.10 Текст и поясняющие надписи.
# В некоторых случаях небольшие текстовые подсказки и метки оказываются необходимы.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd

# %% [markdown]
# Пример: влияние выходных дней на рождение детей в США.
# Загрузим данные из внешних источников.

# %%
# !wget https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv
# Out:
# --2022-11-23 11:46:39--  https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 264648 (258K) [text/plain]
# Saving to: ‘births.csv’
#
# births.csv          100%[===================>] 258.45K  --.-KB/s    in 0.03s
#
# 2022-11-23 11:46:39 (8.14 MB/s) - ‘births.csv’ saved [264648/264648]

# %% [markdown]
# Воспользуемся библиотекой Pandas  для обработки данных.

# %%
births = pd.read_csv('births.csv')

# %%
births.head() # вывели первые пять строчек
# Out:
#             year  month  day gender  births
# 1969-01-01  1969      1    1      F    4046
# 1969-01-01  1969      1    1      M    4440
# 1969-01-02  1969      1    2      F    4454
# 1969-01-02  1969      1    2      M    4548
# 1969-01-03  1969      1    3      F    4548

# %%
quartiles = np.percentile(births['births'], [25, 50, 75])
mu, sig = quartiles[1], 0.74 * (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & (births < @mu + 5 * @sig)')

births['day'] = births['day'].astype(int)
births.index = pd.to_datetime(10000 * births.year + 100 * births.month + births.day, format='%Y%m%d')

births_by_date = births.pivot_table('births', [births.index.month, births.index.day])

births_by_date.index = [pd.datetime(2012, month, day) for (month, day) in births_by_date.index]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
fig, ax = plt.subplots(figsize=(12, 4))
ax.set_title('Среднее ежедневное количество новорожденных в зависимости от даты')
births_by_date.plot(ax=ax)

# %% [markdown]
# При работе с данными подобным образом часто бывает полезно снабдить элементы графика пояснениями для привлечения к ним внимания читателя. Это можно сделать вручную с помощью команды `plt.text/ax.text` , которая поместит текст в месте, соответствующем конкретным значениям координат (x, y)

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)
# Добавляем метки на график
style = dict(size=10, color='gray')
ax.text('2012-1-1', 3950, "Новый год", **style)
ax.text('2012-7-4', 4250, "День Независимости", ha='center', **style)
ax.text('2012-9-4', 4850, "День Труда", ha='center', **style)
ax.text('2012-10-31', 4600, "Хеллоуин", ha='right', **style)
ax.text('2012-11-25', 4450, "День Благодарения", ha='center', **style)
ax.text('2012-12-25', 3850, "Рождество", ha='right', **style)
# Добавляем метки для осей координат
ax.set(title='Ежедневное количество рождаемых детей в зависимости от даты, с комментариями',
ylabel='среднесуточные рождения')
# Размечаем ось X центрированными метками для месяцев
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'))

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Используя материалы текущего задания, поэкспериментируйте с использованием различных цветов и стилей подписей, добавлением новых дат.

# %% [markdown]
# ###10.11 Пользовательские настройки делений на осях координат.
# Локаторы и форматеры делений на осях, используемые по умолчанию в библиотеке Matplotlib, спроектированы так, что в большинстве обычных ситуаций их вполне достаточно, хотя они отнюдь не оптимальны для всех графиков.
# На каждой оси координат имеются основные и промежуточные метки делений. Основные деления обычно больше или более заметны, а промежуточные — меньше.

# %%
plt.style.use('seaborn-whitegrid')
ax = plt.axes(xscale='log', yscale='log')

# %% [markdown]
# Можно задать пользовательские настройки для этих свойств делений (расположений и меток), задав значения объектов `formatter` и `locator` каждой из осей.

# %%
print(ax.xaxis.get_major_locator())
print(ax.xaxis.get_minor_locator())

# %%
print(ax.xaxis.get_major_formatter())
print(ax.xaxis.get_minor_formatter())

# %% [markdown]
# Расположение меток как основных, так и промежуточных делений
# задает локатор `LogLocator` (что логично для логарифмического графика). Метки промежуточных делений форматируются форматером `NullFormatter` (это означает, что метки отображаться не будут)

# %% [markdown]
# Наиболее частая операция с делениями/метками — скрывание делений или меток с помощью классов `plt.NullLocator()` и `plt.NullFormatter()`

# %%
ax = plt.axes()
ax.plot(np.random.rand(50))
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %% [markdown]
# Уменьшение или увеличение количества делений.

# %%
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

# %%
# Задаем, для всех систем координат, локаторы основных делений осей X и Y
for axi in ax.flat:
  axi.xaxis.set_major_locator(plt.MaxNLocator(4))
  axi.yaxis.set_major_locator(plt.MaxNLocator(4))
  axi.xaxis.set_major_formatter(plt.ScalarFormatter(1))
  axi.yaxis.set_major_formatter(plt.ScalarFormatter(1))
fig

# %% [markdown]
# **Краткая сводка локаторы**
#
# Класс локатора | Описание
# *  `NullLocator` - Без делений
# *  `FixedLocator` - Положения делений фиксированы
# *  `IndexLocator` -  Локатор для графика индексированной переменной (например, для x = range(len(y)))
# *  `LinearLocator` - Равномерно распределенные деления от min до max
# *  `LogLocator` - Логарифмически распределенные деления от min до max
# *  `MultipleLocator` - Деления и диапазон значений кратны заданному основанию
# *  `MaxNLocator` - Находит удачные местоположения для делений в количестве, не превышающем заданного максимального числа
# *  `AutoLocator` (По умолчанию.) MaxNLocator с простейшими значениями по умолчанию
# *  `AutoMinorLocator` Локатор для промежуточных делений

# %% [markdown]
# **Краткая сводка форматеры**
#
# Класс форматера | Описание
# *  `NullFormatter` - Деления без меток
# *  `IndexFormatter` - Задает строковые значения для меток на основе списка меток
# *  `FixedFormatter` - Позволяет задавать строковые значения для меток вручную
# *  `FuncFormatter` - Значения меток задаются с помощью пользовательской функции
# *  `FormatStrFormatter` - Для всех значений используется строка формата
# *  `ScalarFormatter` - (По умолчанию.) Форматер для скалярных значений
# *  `LogFormatter` - Форматер по умолчанию для логарифмических систем координат

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Используя материалы текущего задания, поэкспериментируйте с использованием различных локаторов и форматеров

# %%
ax = plt.axes()
ax.plot(np.random.rand(50))
ax.yaxis.set_major_locator(plt.LinearLocator(3))
ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%f'))

# %% [markdown]
# ###10.12 Пользовательские настройки Matplotlib: конфигурации и таблицы стилей.
# Умение настраивать значения по умолчанию поможет привести этот пакет Matplotlib в соответствие с собственными эстетическими предпочтениями.

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
import numpy as np
# %matplotlib inline

# %%
x = np.random.randn(1000)
plt.title('Гистограмма в стиле библиотеки Matplotlib по умолчанию')
plt.hist(x)
# Out:
# (array([  1.,   2.,   5.,  36., 176., 291., 297., 147.,  41.,   4.]),
#  array([-4.86350518, -4.04689997, -3.23029477, -2.41368956, -1.59708435,
#         -0.78047914,  0.03612607,  0.85273128,  1.66933649,  2.4859417 ,
#          3.30254691]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Можно настроить вид вручную, превратив эту гистограмму в намного более приятный глазу график.

# %%
# Используем серый фон
ax = plt.axes(facecolor='#99FFFF') # axisbg
ax.set_axisbelow(True)

# Рисуем сплошные белые линии сетки
plt.grid(color='w', linestyle='solid')

# Скрываем основные линии осей координат
for spine in ax.spines.values():
  spine.set_visible(False)

# Скрываем деления сверху и справа
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
# Осветляем цвет делений и меток
ax.tick_params(colors='gray', direction='out')
for tick in ax.get_xticklabels():
  tick.set_color('gray')
for tick in ax.get_yticklabels():
  tick.set_color('gray')
plt.title('Гистограмма с заданными вручную пользовательскими настройками')
# Задаем цвет заливки и границ гистограммы
ax.hist(x, edgecolor='#CCCCCC', color='#808A87')
# Out:
# (array([  1.,   2.,   5.,  36., 176., 291., 297., 147.,  41.,   4.]),
#  array([-4.86350518, -4.04689997, -3.23029477, -2.41368956, -1.59708435,
#         -0.78047914,  0.03612607,  0.85273128,  1.66933649,  2.4859417 ,
#          3.30254691]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# **Изменяем значения по умолчанию: rcParams**
#
# При загрузке библиотеки Matplotlib она описывает конфигурацию
# среды `(rc)`, содержащую стили по умолчанию для всех создаваемых вами элементов графиков. Эту конфигурацию можно настроить в любой момент, воспользовавшись
# удобной утилитой `plt.rc` .

# %%
IPython_default = plt.rcParams.copy() # сохраненим копии текущего словаря rcParams, для возможности восстановления

# %%
from matplotlib import cycler
colors = cycler('color',
['#808A87', '#3388BB', '#9988DD',
'#EECC55', '#88BB44', '#FFBBBB'])
plt.rc('axes', facecolor='#99FFFF', edgecolor='none',
axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#CCCCCC')
plt.rc('lines', linewidth=2)

# %%
plt.title('Пользовательская гистограмма с настройками rc')
plt.hist(x) # Описав эти настройки, можно создать график и посмотреть на них в действии
# Out:
# (array([  1.,   2.,   5.,  36., 176., 291., 297., 147.,  41.,   4.]),
#  array([-4.86350518, -4.04689997, -3.23029477, -2.41368956, -1.59708435,
#         -0.78047914,  0.03612607,  0.85273128,  1.66933649,  2.4859417 ,
#          3.30254691]),
#  <a list of 10 Patch objects>)

# %%
plt.title('Линейный график с пользовательскими стилями')
for i in range(4):
  plt.plot(np.random.rand(10))

# %% [markdown]
# **Таблицы стилей**
#
# В Matplotlib есть удобный модуль style, включающий немало новых таблиц стилей по умолчанию, а также возможность создавать и компоновать пользовательские стили.
#
# Включенные по умолчанию таблицы стилей очень удобны.

# %%
plt.style.available # посмотрить имеющиеся стили
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# Простейший способ переключения таблиц стилей — вызвать функцию:
# `plt.style.use('stylename')`
#
# НО! это приведет к изменению стиля на весь остаток сеанса! В качестве альтернативы можно воспользоваться контекстным менеджером стилей,
# устанавливающим стиль временно:
#
# `with plt.style.context('stylename'):`
#
# .....`make_a_plot()`

# %%
# Создадим функцию, рисующую два простейших вида графиков:
def hist_and_lines():
  np.random.seed(0)
  fig, ax = plt.subplots(1, 2, figsize=(11, 4))
  ax[0].hist(np.random.randn(1000))
  for i in range(3):
    ax[1].plot(np.random.rand(10))
  ax[1].legend(['a', 'b', 'c'], loc='lower left')

# %% [markdown]
# Пробуем отобразить графики разными стилями

# %%
# Стиль по умолчанию
# plt.rcParams.update(IPython_default)
hist_and_lines()

# %%
with plt.style.context('fivethirtyeight'): # Стиль FiveThirtyEight
  hist_and_lines()

# %%
with plt.style.context('ggplot'): # Стиль ggplot — очень популярное средство визуализации.
  hist_and_lines()

# %%
with plt.style.context('bmh'): # Стиль «байесовские методы для хакеров»
  hist_and_lines()

# %%
with plt.style.context('dark_background'): # Темный фон
  hist_and_lines()

# %%
with plt.style.context('seaborn'): # Стиль Seaborn
  hist_and_lines()

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Используя материалы текущего задания, поэкспериментируйте с использованием различных стилей

# %%
a=np.array(['Solarize_Light2',
            '_classic_test_patch',
            'bmh',
            'classic',
            'dark_background',
            'fast',
            'fivethirtyeight',
            'ggplot',
            'seaborn-white',
            'seaborn-whitegrid',
            'tableau-colorblind10'])

with plt.style.context(a[0]): 
  hist_and_lines()

with plt.style.context(a[1]): 
  hist_and_lines()

with plt.style.context(a[2]): 
  hist_and_lines()

with plt.style.context(a[5]): 
  hist_and_lines()

with plt.style.context(a[-3]): 
  hist_and_lines()

# %% [markdown]
# ###10.13 Построение трехмерных графиков в библиотеке Matplotlib.
# Активизируем возможность построения трехмерных
# графиков путем импорта набора инструментов mplot3d , включенного в основной установочный пакет библиотеки Matplotlib.

# %%
from mpl_toolkits import mplot3d

# %% [markdown]
# После импорта этого подмодуля появляется возможность создавать трехмерные системы координат путем передачи ключевого слова projection='3d' любой из обычных функций создания систем координат:

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %% [markdown]
# **Трехмерные точки и линии**
#
# По аналогии с обсуждавшимися ранее более распространенными двумерными графиками их можно создать с помощью функций `ax.plot3D` и `ax.scatter3D`.

# %%
ax = plt.axes(projection='3d')
# Данные для трехмерной кривой
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')
# Данные для трехмерных точек
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.set_title('Точки и линии в трех измерениях')
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens')

# %% [markdown]
# **Трехмерные контурные графики**
#
# Аналогично контурным графикам, mplot3d содержит инструменты для
# создания трехмерных рельефных графиков на основе тех же входных данных. Подобно двумерным графикам, создаваемым с помощью функции `ax.contour`, для функции `ax.contour3D` необходимо, чтобы все входные данные находились в форме двумерных регулярных сеток, с вычислением данных по оси Z в каждой точке.

# %%
def f(x, y):
  return np.sin(np.sqrt(x ** 2 + y ** 2))
x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('Трехмерный контурный график')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# /usr/local/lib/python3.7/dist-packages/mpl_toolkits/mplot3d/art3d.py:304: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self._segments3d = np.asanyarray(segments)
# Text(0.5, 0, 'z')

# %% [markdown]
# Можно воспользоваться методом `view_init` для задания угла возвышения и азимутального угла.

# %%
ax.view_init(60, 35)
fig

# %% [markdown]
# **Каркасы и поверхностные графики**
#
# Каркасы и поверхностные графики — еще два типа трехмерных графиков, подходящих для данных с привязкой к координатам. Они выполняют проекцию координатных значений на заданную трехмерную поверхность, облегчая наглядное представление полученных трехмерных фигур.

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='black')
ax.set_title('График каркаса'); # Каркас

# %% [markdown]
# Поверхностный график аналогичен графику каркаса, но каждая грань представляет собой заполненный многоугольник.

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none') # Поверхность
ax.set_title('Трехмерный поверхностный график');

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Используя материалы текущего задания, задайте собственную трехмерную функцию.
# 2.   Визуализируйте ее с помощью трехмерных точек и линий
# 3.   Визуализируйте ее с помощью трехмерной контурной графики
# 4.   Визуализируйте ее с помощью каркасов и поверхностных графиков
# 5.   Поэкперементируйте с различными параметрами, каждой из технологий отображения
# 6.   Отразите различные виды возвышения и азимутального угла

# %% [markdown]
# ###10.14 Отображение географических данных с помощью Basemap.
# Визуализация географических данных — распространенный вид визуализации в науке о данных. Для этой цели предназначена утилита библиотеки Matplotlib — набор программ Basemap

# %%
# !pip install basemap

# %%
from mpl_toolkits.basemap import Basemap

# %%
plt.figure(figsize=(8, 8))
m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)
m.bluemarble(scale=0.5)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Отображаемая на рисунке сфера — не просто изображение,
# это полнофункциональная система координат Matplotlib, понимающая сферические координаты и позволяющая легко дорисовывать данные на карту.

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution=None,
          width=8E6, height=8E6,lat_0=32, lon_0=60,)
m.etopo(scale=0.5, alpha=0.5)
# Проецируем кортеж (долгота, широта) на координаты (x, y)
# для построения графика
x, y = m(37.617698,55.755864)
plt.plot(x, y, 'ok', markersize=5)
plt.text(x, y, ' Москва', fontsize=12)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(2464980.5773851443, 6886765.923419373, ' Москва')

# %% [markdown]
# Приведенный пример позволяет понять, какие географические визуализации возможны с помощью всего нескольких строк кода на языке Python.

# %% [markdown]
# ### **Практическое задание**
#
# 1.   Используя материалы текущего задания, разместите название и местоположение города Владивосток на соответсвующем участке карты. Долготу и широту города необходимо взять из открытых источников.

# %% [markdown]
# ###10.15 Визуализация с помощью библиотеки Seaborn.
# Библиотека Seaborn Seaborn предоставляет API поверх
# библиотеки Matplotlib, обеспечивающий разумные варианты стилей графиков и цветов по умолчанию, определяющий простые высокоуровневые функции для часто встречающихся типов графиков и хорошо интегрирующийся с функциональностью, предоставляемой объектами DataFrame библиотеки Pandas.
#
# Основная идея библиотеки Seaborn — предоставление высокоуровневых команд для создания множества различных типов графиков, удобных для исследования статистических данных и даже подгонки статистических моделей.

# %%
import numpy as np
import seaborn as sns # По принятым соглашениям Seaborn импортируется под именем sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Создаем данные
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
sns.set() # Задать стиль можно с помощью метода set()

# %%
plt.plot(x, y)
plt.title('Данные в используемом по умолчанию стиле библиотеки Seaborn')
plt.legend('ABCDEF', ncol=2, loc='upper left')

# %% [markdown]
# **Гистограммы, KDE и плотности**
#
# Зачастую все, что нужно сделать при визуализации статистических данных, — это построить гистограмму и график совместного распределения переменных.

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
data.head(10)
# Out:
#           x         y
# 0 -0.339514 -1.056772
# 1  1.949940 -0.323523
# 2  1.810144  0.096644
# 3  1.400761  1.282802
# 4 -1.472639 -1.649352
# 5  1.572179  0.457619
# 6  2.236997  2.045250
# 7  1.844546 -1.491620
# 8 -0.704560 -1.555935
# 9  3.755424  1.360152

# %%
plt.title('Гистограммы для визуализации распределений')
sns.histplot(data=data, bins=10 ,alpha=0.5)

# %%
plt.title('Использование ядерной оценки плотности для визуализации распределений')
sns.kdeplot(data=data, shade=True)

# %%
sns.jointplot(x="x", y="y", data=data) # График совместного распределения с разбиением по интервалам

# %% [markdown]
# При обобщении графиков совместных распределений на наборы данных более высоких размерностей, возникает необходимость исследования графиков пар (pair plots). Они очень удобны для изучения зависимостей между многомерными данными, когда
# необходимо построить график всех пар значений.
#
# Продемонстрируем это на  наборе данных *Iris*, содержащем
# измерения лепестков и чашелистиков трех видов ирисов:

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Визуализация многомерных зависимостей между выборками сводится к вызову функции `sns.pairplot`

# %%
sns.pairplot(iris, hue='species', height=2.5)

# %%
sns.boxplot(data=iris)

# %% [markdown]
# ### **Практическое задание**
# 1.  С помощью библиотеки Seaborn реализуйте максимально возможное количесто заданий ранее выполненных средствами Matplotlib

# %% [markdown]
# ###10.16 Дополнительная литература
#
#
# 1.   https://pandas.pydata.org/pandas-docs/stable/api.html#api-dataframe-plotting – справочник по
# графикам в pandas с использованием Matplotlib
# 1.   https://pandas.pydata.org/pandas-docs/stable/visualization.html -- примеры графиков
# 1.   https://seaborn.pydata.org/api.html -- справочник по возможностям Seaborn
# 1.   https://seaborn.pydata.org/examples/index.html -- примеры графиков Seaborn
# 2.   http://malev.ru/анализ-данных-при-помощи-python-графики-в-pandas/ -- что-то про Matplotlib
# 2.   https://habrahabr.ru/company/ods/blog/323210/ -- немного про Seaborn
